# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %cd /content/drive/MyDrive

# !git clone https://github.com/9Knight9n/crawler-legislation-uk.git
# Out:
# /content/drive/MyDrive
# Cloning into 'crawler-legislation-uk'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 109 (delta 51), reused 83 (delta 29), pack-reused 0
# Receiving objects: 100% (109/109), 29.65 KiB | 1.74 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# %cd crawler-legislation-uk
# Out:
# /content/drive/MyDrive/crawler-legislation-uk

# %%
# !python run.py
# Out:
# total processed acts :20
# total processed acts :40
# total processed acts :60
# total processed acts :80
# total processed acts :100
# total processed acts :120
# total processed acts :140
# total processed acts :160
# total processed acts :180
# total processed acts :200
# total processed acts :220
# total processed acts :240
# total processed acts :260
# total processed acts :280
# total processed acts :300
# total processed acts :320
# total processed acts :340
# total processed acts :360
# total processed acts :380
# total processed acts :400
# total processed acts :420
# total processed acts :440
# total processed acts :460
# total processed acts :480
# Traceback (most recent call last):
#   File "run.py", line 22, in <module>
#     append_act(act)
#   File "/content/crawler-legislation-uk/save/act.py", line 38, in append_act
#     act_detail = get_act_details(p_id)
#   File "/content/crawler-legislation-uk/extract/act.py", line 14, in get_act_details
# ...

# %%
# !zip -r /content/drive/MyDrive/file.zip /content/crawler-legislation-uk
# Out:
#   adding: content/crawler-legislation-uk/ (stored 0%)
#   adding: content/crawler-legislation-uk/run.py (deflated 56%)
#   adding: content/crawler-legislation-uk/save/ (stored 0%)
#   adding: content/crawler-legislation-uk/save/act.py (deflated 63%)
#   adding: content/crawler-legislation-uk/save/type_list.py (deflated 41%)
#   adding: content/crawler-legislation-uk/save/__init__.py (deflated 60%)
#   adding: content/crawler-legislation-uk/save/__pycache__/ (stored 0%)
#   adding: content/crawler-legislation-uk/save/__pycache__/__init__.cpython-37.pyc (deflated 32%)
#   adding: content/crawler-legislation-uk/save/__pycache__/act.cpython-37.pyc (deflated 38%)
#   adding: content/crawler-legislation-uk/requirements.txt (deflated 3%)
#   adding: content/crawler-legislation-uk/README.md (deflated 61%)
#   adding: content/crawler-legislation-uk/.gitignore (deflated 46%)
#   adding: content/crawler-legislation-uk/.idea/ (stored 0%)
# ...
